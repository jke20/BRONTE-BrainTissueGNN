# %% [markdown]
# # Merge modules from WGCNA
# #### Jianfeng
# #### 05/14/2024

# %%
# import libraries
# import torch
# import torch.nn.functional as F
# from torch_geometric.nn import GCNConv
import os
import csv
import copy
import math
import time
import random
import pickle
import argparse
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tools.eval_measures import mse
from scipy import stats
from scipy.stats import spearmanr
from scipy.spatial.distance import cosine
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
# Load gtex data
data_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/12052023/'
gt = pd.read_csv(data_dir+"new_normed_gtex_gtex_allen_gene.txt", low_memory=False, index_col=0, sep="\t")
region_pick = ['Amygdala', 'Anterior_cingulate_cortex_BA24', 'Caudate_basal_ganglia', 
               'Cerebellar_Hemisphere', 'Frontal_Cortex_BA9', 'Hippocampus', 'Hypothalamus', 
               'Nucleus_accumbens_basal_ganglia', 'Putamen_basal_ganglia', 'Substantia_nigra']

# build a dictionary to count the freq of each subject 
sample_subject_list = gt.loc['subject'].tolist()
subject_region_mat = pd.DataFrame(np.zeros((len(set(sample_subject_list)), len(region_pick)), dtype=int))
subject_region_mat.index = sorted(set(sample_subject_list))
subject_region_mat.columns = region_pick
for i in range(gt.shape[1]):
    region = gt.loc['region'][i]
    subject = gt.loc['subject'][i]
    region_idx = region_pick.index(region)
    subject_idx = subject_region_mat.index.tolist().index(subject)
    subject_region_mat.iloc[subject_idx, region_idx] = 1

# %%
# find ME for each module, {'M1': ['A1BG', 'A2M', 'A2ML1'], 'M2':...}
# output is the module-MEs dictionary
def find_ME(go_mat, input_dict):
    ME_dict = {}
    for key, value in input_dict.items():
        exp_mat = go_mat.loc[value]
        pca = PCA(n_components=1)
        pca.fit(exp_mat)
        ME = pca.components_[0]
        ME_dict[key] = ME
        
    return ME_dict


def find_max_element(mat):
    max_value = -2
    max_value_pos = [0, 0]
    for i in range(len(mat)):
        for j in range(i+1, len(mat)):
            if mat.iloc[i,j] > max_value:
                max_value = mat.iloc[i,j]
                max_value_pos = [i, j]  
                
    return max_value, max_value_pos
                

def merge_module(input_dict):
    ME_dict = find_ME(go_mat, input_dict)
    ME_mat = pd.DataFrame(ME_dict)
    module_list = list(input_dict.keys())
    corr_mat = ME_mat.corr()
    max_corr, max_corr_pair = find_max_element(corr_mat)
    # print(f'Max correlation between two modules is {max_corr}')
    mod1_idx, mod2_idx = max_corr_pair
    new_dict = input_dict.copy()
    # print(f'The module to extend: {module_list[mod1_idx]}, there are {len(input_dict[module_list[mod1_idx]])} in this module')
    # print(f'The module to remove: {module_list[mod2_idx]}, there are {len(input_dict[module_list[mod2_idx]])} in this module')
    if max_corr>0.8:
        new_dict[module_list[mod1_idx]].extend(new_dict.pop(module_list[mod2_idx]))
        # print(f'Now there are {len(new_dict[module_list[mod1_idx]])} in module {module_list[mod1_idx]} in the new dict')
    # print(f'After merging modules, the number of modules left: {len(new_dict.keys())}')
        
    return new_dict


def reassign_gene_to_module(go_mat, input_dict):
    ME_dict = find_ME(go_mat, input_dict)
    ME_mat = pd.DataFrame(ME_dict)
    module_list = ME_mat.columns.tolist()
    gene_list = go_mat.index.tolist()
    kME_mat = np.corrcoef(ME_mat.T, go_mat)[len(ME_mat.T):(len(go_mat)+len(ME_mat.T)), :len(ME_mat.T)]
    # create a new dictionary with same modules
    new_dict = {}
    for mod in module_list:
        new_dict[mod] = []
    for i in range(len(gene_list)):
        gene_name = gene_list[i]
        gene_kME = kME_mat[i]
        mod = module_list[np.argmax(gene_kME)]
        new_dict[mod].append(gene_name)
    # remove key with no genes
    # new_dict = {k: v for k, v in new_dict.items() if v}
    
    return new_dict


# compare the original dict and the new dict, 
# find the module for which the largest number of genes were reassigned,
# if <70% of the genes in this module remain in the module after re-assignment, remove the module
def check_after_reassign(new_dict, input_dict):
    reassign_number_list = []
    module_list = list(input_dict.keys())
    for mod in module_list:
        count = 0
        old_genes = input_dict[mod]
        new_genes = new_dict[mod]
        for gene in old_genes:
            if gene in new_genes:
                count = count + 1
        reassign_number_list.append(count/len(old_genes))
        print(f'{count}/{len(old_genes)}')
    min_value = reassign_number_list[np.argmin(reassign_number_list)]
    pick_mod = module_list[np.argmin(reassign_number_list)]
    
    return pick_mod, min_value


# remove empty module
def clear_empty_module(input_dict):
    new_dict = {k: v for k, v in input_dict.items() if v}
    if len(new_dict.keys())<len(input_dict.keys()):
        diff = len(input_dict.keys())-len(new_dict.keys())
        # print(f'There are empty modules, removing {diff} empty modules')
    
    return new_dict


# remove the module after reassignment
# input a dictionary, and remove a module if needed, output a new dict afterward
def remove_module(go_mat, input_dict, pick_mod):
    ME_dict = find_ME(go_mat, input_dict)
    ME_mat = pd.DataFrame(ME_dict)
    module_list = ME_mat.columns.tolist()
    gene_list = go_mat.index.tolist()
    kME_mat = np.corrcoef(ME_mat.T, go_mat)[len(ME_mat.T):(len(go_mat)+len(ME_mat.T)), :len(ME_mat.T)]
    # create a new dictionary with same modules
    update_dict = {}
    pick_mod_idx = module_list.index(pick_mod)
    new_kME_mat = np.delete(kME_mat, pick_mod_idx, axis=1)
    # remove the module from keys
    module_list.pop(pick_mod_idx)
    for mod in module_list:
        update_dict[mod] = []
    for i in range(len(gene_list)):
        gene_name = gene_list[i]
        gene_kME = new_kME_mat[i]
        mod = module_list[np.argmax(gene_kME)]
        update_dict[mod].append(gene_name)
    
    return update_dict


# merge modules
def MERGE_WORKFLOW(go_mat, input_dict):
    ME_dict = find_ME(go_mat, input_dict)
    merged_input_dict = merge_module(input_dict)
    while len(merged_input_dict.keys()) < len(input_dict.keys()):
        input_dict = merged_input_dict.copy()
        merged_input_dict = merge_module(input_dict)
    # print(f'End merging module phase 1. The number of modules left: {len(merged_input_dict.keys())}\n')
    # print('Starting steps for coherency and incoherent:')
    # reassign_dict = reassign_gene_to_module(go_mat, merged_input_dict)
    # pick_mod, min_value = check_after_reassign(reassign_dict, merged_input_dict)
    # while min_value<0.7:
    #     print(f'Min value is {min_value}, and the module to remove is {pick_mod}')
    #     update_dict = remove_module(go_mat, reassign_dict, pick_mod)
    #     reassign_dict = reassign_gene_to_module(go_mat, update_dict)
    #     reassign_dict = clear_empty_module(reassign_dict)
    #     pick_mod, min_value = check_after_reassign(update_dict, reassign_dict)
        
    return merged_input_dict

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# model settings
t_epoch = 300
f_epoch = 500
status = 'trainable'
missing_N = 5
# merge modules for every subject
include_subject = [s for s in subject_region_mat.index if subject_region_mat.loc[s].sum()>=(10-missing_N)]
for subject in include_subject:
    save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/ATG_8_or_less/Prediction/300_500_by_subject/'
    csv_file = f'{subject}_{t_epoch}_{f_epoch}_{status}_LMfromGTEx.csv'
    go_mat = pd.read_csv(save_dir+csv_file, index_col=0)
    # read the raw module output from WGCNA
    filename = f'{subject}_raw_modules.csv'
    save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/WGCNA/raw_modules/'
    module_df = pd.read_csv(save_dir+filename)
    # remove color genes with color 'grey'
    color_list = module_df['Cluster']
    remove_row = [i for i in range(module_df.shape[0]) if color_list[i]=='grey']
    update_df = module_df.drop(remove_row).reset_index(drop=True)
    module_dict = update_df.groupby('Module')['Gene'].apply(list).to_dict()
    update_mat = go_mat.drop(go_mat.index[remove_row])
    print(f'{15044-update_mat.shape[0]} genes with color grey are excluded from analysis for {subject}')
    # check if the file is already exist or not
    save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/WGCNA/output_modules/'
    file_name = f'{subject}_merged_module.csv'
    if os.path.isfile(save_dir+file_name):
        print(f'There is already a file for {subject}!')
        continue
    else:
        # run the merging module function
        output_dict = MERGE_WORKFLOW(update_mat, module_dict)
        # clean the modules
        final_dict = {}
        module_list = list(output_dict.keys())
        for key, value in output_dict.items():
            new_module_name = f'M{module_list.index(key)+1}'
            final_dict[new_module_name] = value
        # save the result 
        data = [(gene, key) for key, genes in final_dict.items() for gene in genes]
        final_mat = pd.DataFrame(data, columns=['gene', 'module'])
        save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/WGCNA/output_modules/'
        file_name = f'{subject}_merged_module.csv'
        final_mat.to_csv(save_dir+file_name, index=False)
        print(f"End merging modules for {subject}!")
# Out:
# 4 genes with color grey are excluded from analysis for GTEX-1192X
# There is already a file for GTEX-1192X!
# 1 genes with color grey are excluded from analysis for GTEX-11DXW
# End merging modules for GTEX-11DXW!
# 2 genes with color grey are excluded from analysis for GTEX-11DXY
# End merging modules for GTEX-11DXY!
# 0 genes with color grey are excluded from analysis for GTEX-11DYG
# End merging modules for GTEX-11DYG!
# 0 genes with color grey are excluded from analysis for GTEX-11DZ1
# End merging modules for GTEX-11DZ1!
# 0 genes with color grey are excluded from analysis for GTEX-11GSP
# End merging modules for GTEX-11GSP!
# 0 genes with color grey are excluded from analysis for GTEX-11OF3
# End merging modules for GTEX-11OF3!
# 0 genes with color grey are excluded from analysis for GTEX-11ONC
# End merging modules for GTEX-11ONC!
# 1 genes with color grey are excluded from analysis for GTEX-11PRG
# End merging modules for GTEX-11PRG!
# 0 genes with color grey are excluded from analysis for GTEX-11TTK
# End merging modules for GTEX-11TTK!
# 0 genes with color grey are excluded from analysis for GTEX-11WQC
# End merging modules for GTEX-11WQC!
# 0 genes with color grey are excluded from analysis for GTEX-11ZTS
# End merging modules for GTEX-11ZTS!
# 0 genes with color grey are excluded from analysis for GTEX-12WSA
# End merging modules for GTEX-12WSA!
# 1 genes with color grey are excluded from analysis for GTEX-12WSC
# End merging modules for GTEX-12WSC!
# 1 genes with color grey are excluded from analysis for GTEX-12WSD
# End merging modules for GTEX-12WSD!
# 0 genes with color grey are excluded from analysis for GTEX-12WSE
# End merging modules for GTEX-12WSE!
# 0 genes with color grey are excluded from analysis for GTEX-12WSF
# End merging modules for GTEX-12WSF!
# 0 genes with color grey are excluded from analysis for GTEX-12WSH
# End merging modules for GTEX-12WSH!
# 0 genes with color grey are excluded from analysis for GTEX-12WSM
# End merging modules for GTEX-12WSM!
# 0 genes with color grey are excluded from analysis for GTEX-12ZZW
# End merging modules for GTEX-12ZZW!
# 0 genes with color grey are excluded from analysis for GTEX-12ZZX
# End merging modules for GTEX-12ZZX!
# 1 genes with color grey are excluded from analysis for GTEX-12ZZZ
# End merging modules for GTEX-12ZZZ!
# 1 genes with color grey are excluded from analysis for GTEX-13112
# End merging modules for GTEX-13112!
# 1 genes with color grey are excluded from analysis for GTEX-1313W
# End merging modules for GTEX-1313W!
# 0 genes with color grey are excluded from analysis for GTEX-131XH
# End merging modules for GTEX-131XH!
# 0 genes with color grey are excluded from analysis for GTEX-131YS
# End merging modules for GTEX-131YS!
# 0 genes with color grey are excluded from analysis for GTEX-132Q8
# End merging modules for GTEX-132Q8!
# 0 genes with color grey are excluded from analysis for GTEX-1399T
# End merging modules for GTEX-1399T!
# 3 genes with color grey are excluded from analysis for GTEX-139TS
# End merging modules for GTEX-139TS!
# 1 genes with color grey are excluded from analysis for GTEX-139TT
# End merging modules for GTEX-139TT!
# 0 genes with color grey are excluded from analysis for GTEX-13CF2
# End merging modules for GTEX-13CF2!
# 0 genes with color grey are excluded from analysis for GTEX-13CZV
# End merging modules for GTEX-13CZV!
# 0 genes with color grey are excluded from analysis for GTEX-13FHO
# End merging modules for GTEX-13FHO!
# 1 genes with color grey are excluded from analysis for GTEX-13FHP
# End merging modules for GTEX-13FHP!
# 0 genes with color grey are excluded from analysis for GTEX-13FLV
# End merging modules for GTEX-13FLV!
# 1 genes with color grey are excluded from analysis for GTEX-13FLW
# End merging modules for GTEX-13FLW!
# 1 genes with color grey are excluded from analysis for GTEX-13FXS
# End merging modules for GTEX-13FXS!
# 0 genes with color grey are excluded from analysis for GTEX-13G51
# End merging modules for GTEX-13G51!
# 0 genes with color grey are excluded from analysis for GTEX-13JUV
# End merging modules for GTEX-13JUV!
# 0 genes with color grey are excluded from analysis for GTEX-13JVG
# End merging modules for GTEX-13JVG!
# 0 genes with color grey are excluded from analysis for GTEX-13N1W
# End merging modules for GTEX-13N1W!
# 0 genes with color grey are excluded from analysis for GTEX-13N2G
# End merging modules for GTEX-13N2G!
# 1 genes with color grey are excluded from analysis for GTEX-13NYB
# End merging modules for GTEX-13NYB!
# 1 genes with color grey are excluded from analysis for GTEX-13NYS
# End merging modules for GTEX-13NYS!
# 0 genes with color grey are excluded from analysis for GTEX-13NZA
# End merging modules for GTEX-13NZA!
# 1 genes with color grey are excluded from analysis for GTEX-13O3O
# End merging modules for GTEX-13O3O!
# 1 genes with color grey are excluded from analysis for GTEX-13O3Q
# End merging modules for GTEX-13O3Q!
# 0 genes with color grey are excluded from analysis for GTEX-13OVH
# End merging modules for GTEX-13OVH!
# 2 genes with color grey are excluded from analysis for GTEX-13OVJ
# End merging modules for GTEX-13OVJ!
# 0 genes with color grey are excluded from analysis for GTEX-13OVL
# End merging modules for GTEX-13OVL!
# 0 genes with color grey are excluded from analysis for GTEX-13OW5
# End merging modules for GTEX-13OW5!
# 0 genes with color grey are excluded from analysis for GTEX-13OW6
# End merging modules for GTEX-13OW6!
# 0 genes with color grey are excluded from analysis for GTEX-13OW7
# End merging modules for GTEX-13OW7!
# 0 genes with color grey are excluded from analysis for GTEX-13OW8
# End merging modules for GTEX-13OW8!
# 0 genes with color grey are excluded from analysis for GTEX-13PVQ
# End merging modules for GTEX-13PVQ!
# 0 genes with color grey are excluded from analysis for GTEX-13QIC
# End merging modules for GTEX-13QIC!
# 1 genes with color grey are excluded from analysis for GTEX-13QJC
# End merging modules for GTEX-13QJC!
# 0 genes with color grey are excluded from analysis for GTEX-13RTJ
# End merging modules for GTEX-13RTJ!
# 0 genes with color grey are excluded from analysis for GTEX-13S7M
# End merging modules for GTEX-13S7M!
# 0 genes with color grey are excluded from analysis for GTEX-13SLW
# End merging modules for GTEX-13SLW!
# 0 genes with color grey are excluded from analysis for GTEX-13SLX
# End merging modules for GTEX-13SLX!
# 0 genes with color grey are excluded from analysis for GTEX-13VXU
# End merging modules for GTEX-13VXU!
# 1 genes with color grey are excluded from analysis for GTEX-13X6I
# End merging modules for GTEX-13X6I!
# 0 genes with color grey are excluded from analysis for GTEX-13X6J
# End merging modules for GTEX-13X6J!
# 0 genes with color grey are excluded from analysis for GTEX-13X6K
# End merging modules for GTEX-13X6K!
# 0 genes with color grey are excluded from analysis for GTEX-1445S
# End merging modules for GTEX-1445S!
# 0 genes with color grey are excluded from analysis for GTEX-144GL
# End merging modules for GTEX-144GL!
# 1 genes with color grey are excluded from analysis for GTEX-145LS
# End merging modules for GTEX-145LS!
# 0 genes with color grey are excluded from analysis for GTEX-145LU
# End merging modules for GTEX-145LU!
# 2 genes with color grey are excluded from analysis for GTEX-145MH
# End merging modules for GTEX-145MH!
# 1 genes with color grey are excluded from analysis for GTEX-145MI
# End merging modules for GTEX-145MI!
# 1 genes with color grey are excluded from analysis for GTEX-147GR
# End merging modules for GTEX-147GR!
# 0 genes with color grey are excluded from analysis for GTEX-14ABY
# End merging modules for GTEX-14ABY!
# 2 genes with color grey are excluded from analysis for GTEX-14ASI
# End merging modules for GTEX-14ASI!
# 0 genes with color grey are excluded from analysis for GTEX-14BIM
# End merging modules for GTEX-14BIM!
# 1 genes with color grey are excluded from analysis for GTEX-14BIN
# End merging modules for GTEX-14BIN!
# 0 genes with color grey are excluded from analysis for GTEX-14C5O
# End merging modules for GTEX-14C5O!
# 0 genes with color grey are excluded from analysis for GTEX-14E7W
# End merging modules for GTEX-14E7W!
# 1 genes with color grey are excluded from analysis for GTEX-14JG1
# End merging modules for GTEX-14JG1!
# 1 genes with color grey are excluded from analysis for GTEX-14JIY
# End merging modules for GTEX-14JIY!
# 0 genes with color grey are excluded from analysis for GTEX-14LZ3
# End merging modules for GTEX-14LZ3!
# 0 genes with color grey are excluded from analysis for GTEX-14PJM
# End merging modules for GTEX-14PJM!
# 1 genes with color grey are excluded from analysis for GTEX-14PJO
# End merging modules for GTEX-14PJO!
# 0 genes with color grey are excluded from analysis for GTEX-14PN4
# End merging modules for GTEX-14PN4!
# 0 genes with color grey are excluded from analysis for GTEX-14PQA
# End merging modules for GTEX-14PQA!
# 1 genes with color grey are excluded from analysis for GTEX-15CHQ
# End merging modules for GTEX-15CHQ!
# 5 genes with color grey are excluded from analysis for GTEX-15DCD
# End merging modules for GTEX-15DCD!
# 0 genes with color grey are excluded from analysis for GTEX-15DYW
# End merging modules for GTEX-15DYW!
# 0 genes with color grey are excluded from analysis for GTEX-15EO6
# End merging modules for GTEX-15EO6!
# 0 genes with color grey are excluded from analysis for GTEX-15ER7
# End merging modules for GTEX-15ER7!
# 0 genes with color grey are excluded from analysis for GTEX-15G19
# End merging modules for GTEX-15G19!
# 0 genes with color grey are excluded from analysis for GTEX-16NPV
# End merging modules for GTEX-16NPV!
# 0 genes with color grey are excluded from analysis for GTEX-16XZZ
# End merging modules for GTEX-16XZZ!
# 0 genes with color grey are excluded from analysis for GTEX-16YQH
# End merging modules for GTEX-16YQH!
# 2 genes with color grey are excluded from analysis for GTEX-16Z82
# End merging modules for GTEX-16Z82!
# 1 genes with color grey are excluded from analysis for GTEX-17EVP
# End merging modules for GTEX-17EVP!
# 0 genes with color grey are excluded from analysis for GTEX-17EVQ
# End merging modules for GTEX-17EVQ!
# 1 genes with color grey are excluded from analysis for GTEX-17F97
# End merging modules for GTEX-17F97!
# 1 genes with color grey are excluded from analysis for GTEX-17HG3
# End merging modules for GTEX-17HG3!
# 0 genes with color grey are excluded from analysis for GTEX-17HHY
# End merging modules for GTEX-17HHY!
# 2 genes with color grey are excluded from analysis for GTEX-17HII
# End merging modules for GTEX-17HII!
# 0 genes with color grey are excluded from analysis for GTEX-183WM
# End merging modules for GTEX-183WM!
# 0 genes with color grey are excluded from analysis for GTEX-18464
# End merging modules for GTEX-18464!
# 1 genes with color grey are excluded from analysis for GTEX-18465
# End merging modules for GTEX-18465!
# 0 genes with color grey are excluded from analysis for GTEX-18A6Q
# End merging modules for GTEX-18A6Q!
# 0 genes with color grey are excluded from analysis for GTEX-1A3MX
# End merging modules for GTEX-1A3MX!
# 0 genes with color grey are excluded from analysis for GTEX-1A8G6
# End merging modules for GTEX-1A8G6!
# 0 genes with color grey are excluded from analysis for GTEX-1AX9I
# End merging modules for GTEX-1AX9I!
# 0 genes with color grey are excluded from analysis for GTEX-1B8L1
# End merging modules for GTEX-1B8L1!
# 1 genes with color grey are excluded from analysis for GTEX-1B8SF
# End merging modules for GTEX-1B8SF!
# 1 genes with color grey are excluded from analysis for GTEX-1B933
# End merging modules for GTEX-1B933!
# 1 genes with color grey are excluded from analysis for GTEX-1B996
# End merging modules for GTEX-1B996!
# 0 genes with color grey are excluded from analysis for GTEX-1BAJH
# End merging modules for GTEX-1BAJH!
# 0 genes with color grey are excluded from analysis for GTEX-1C64N
# End merging modules for GTEX-1C64N!
# 1 genes with color grey are excluded from analysis for GTEX-1C6VR
# End merging modules for GTEX-1C6VR!
# 1 genes with color grey are excluded from analysis for GTEX-1C6WA
# End merging modules for GTEX-1C6WA!
# 1 genes with color grey are excluded from analysis for GTEX-1CB4G
# End merging modules for GTEX-1CB4G!
# 0 genes with color grey are excluded from analysis for GTEX-1CB4H
# End merging modules for GTEX-1CB4H!
# 2 genes with color grey are excluded from analysis for GTEX-1CB4J
# End merging modules for GTEX-1CB4J!
# 1 genes with color grey are excluded from analysis for GTEX-1E1VI
# End merging modules for GTEX-1E1VI!
# 1 genes with color grey are excluded from analysis for GTEX-1E2YA
# End merging modules for GTEX-1E2YA!
# 0 genes with color grey are excluded from analysis for GTEX-1EH9U
# End merging modules for GTEX-1EH9U!
# 0 genes with color grey are excluded from analysis for GTEX-1EKGG
# End merging modules for GTEX-1EKGG!
# 1 genes with color grey are excluded from analysis for GTEX-1EMGI
# End merging modules for GTEX-1EMGI!
# 0 genes with color grey are excluded from analysis for GTEX-1EX96
# End merging modules for GTEX-1EX96!
# 1 genes with color grey are excluded from analysis for GTEX-1F48J
# End merging modules for GTEX-1F48J!
# 0 genes with color grey are excluded from analysis for GTEX-1F52S
# End merging modules for GTEX-1F52S!
# 1 genes with color grey are excluded from analysis for GTEX-1F6I4
# End merging modules for GTEX-1F6I4!
# 1 genes with color grey are excluded from analysis for GTEX-1F6IF
# End merging modules for GTEX-1F6IF!
# 1 genes with color grey are excluded from analysis for GTEX-1F75A
# End merging modules for GTEX-1F75A!
# 1 genes with color grey are excluded from analysis for GTEX-1F75W
# End merging modules for GTEX-1F75W!
# 0 genes with color grey are excluded from analysis for GTEX-1F7RK
# End merging modules for GTEX-1F7RK!
# 3 genes with color grey are excluded from analysis for GTEX-1GF9V
# End merging modules for GTEX-1GF9V!
# 0 genes with color grey are excluded from analysis for GTEX-1GF9W
# End merging modules for GTEX-1GF9W!
# 3 genes with color grey are excluded from analysis for GTEX-1GMR8
# End merging modules for GTEX-1GMR8!
# 1 genes with color grey are excluded from analysis for GTEX-1GMRU
# End merging modules for GTEX-1GMRU!
# 2 genes with color grey are excluded from analysis for GTEX-1GN1U
# End merging modules for GTEX-1GN1U!
# 0 genes with color grey are excluded from analysis for GTEX-1GN2E
# End merging modules for GTEX-1GN2E!
# 0 genes with color grey are excluded from analysis for GTEX-1GN73
# End merging modules for GTEX-1GN73!
# 0 genes with color grey are excluded from analysis for GTEX-1GTWX
# End merging modules for GTEX-1GTWX!
# 0 genes with color grey are excluded from analysis for GTEX-1GZ2Q
# End merging modules for GTEX-1GZ2Q!
# 0 genes with color grey are excluded from analysis for GTEX-1GZ4I
# End merging modules for GTEX-1GZ4I!
# 0 genes with color grey are excluded from analysis for GTEX-1H1CY
# End merging modules for GTEX-1H1CY!
# 0 genes with color grey are excluded from analysis for GTEX-1H1DG
# End merging modules for GTEX-1H1DG!
# 1 genes with color grey are excluded from analysis for GTEX-1H1ZS
# End merging modules for GTEX-1H1ZS!
# 1 genes with color grey are excluded from analysis for GTEX-1H23P
# End merging modules for GTEX-1H23P!
# 0 genes with color grey are excluded from analysis for GTEX-1H3NZ
# End merging modules for GTEX-1H3NZ!
# 0 genes with color grey are excluded from analysis for GTEX-1H3O1
# End merging modules for GTEX-1H3O1!
# 1 genes with color grey are excluded from analysis for GTEX-1H3VE
# End merging modules for GTEX-1H3VE!
# 0 genes with color grey are excluded from analysis for GTEX-1H4P4
# End merging modules for GTEX-1H4P4!
# 0 genes with color grey are excluded from analysis for GTEX-1HB9E
# End merging modules for GTEX-1HB9E!
# 0 genes with color grey are excluded from analysis for GTEX-1HBPH
# End merging modules for GTEX-1HBPH!
# 0 genes with color grey are excluded from analysis for GTEX-1HBPI
# End merging modules for GTEX-1HBPI!
# 0 genes with color grey are excluded from analysis for GTEX-1HCU6
# End merging modules for GTEX-1HCU6!
# 2 genes with color grey are excluded from analysis for GTEX-1HFI6
# End merging modules for GTEX-1HFI6!
# 0 genes with color grey are excluded from analysis for GTEX-1HGF4
# End merging modules for GTEX-1HGF4!
# 0 genes with color grey are excluded from analysis for GTEX-1HSKV
# End merging modules for GTEX-1HSKV!
# 3 genes with color grey are excluded from analysis for GTEX-1HT8W
# End merging modules for GTEX-1HT8W!
# 1 genes with color grey are excluded from analysis for GTEX-1I1CD
# End merging modules for GTEX-1I1CD!
# 0 genes with color grey are excluded from analysis for GTEX-1I1GQ
# End merging modules for GTEX-1I1GQ!
# 0 genes with color grey are excluded from analysis for GTEX-1I1GR
# End merging modules for GTEX-1I1GR!
# 0 genes with color grey are excluded from analysis for GTEX-1I1GS
# End merging modules for GTEX-1I1GS!
# 0 genes with color grey are excluded from analysis for GTEX-1I1GV
# End merging modules for GTEX-1I1GV!
# 0 genes with color grey are excluded from analysis for GTEX-1I1HK
# End merging modules for GTEX-1I1HK!
# 0 genes with color grey are excluded from analysis for GTEX-1ICLZ
# End merging modules for GTEX-1ICLZ!
# 1 genes with color grey are excluded from analysis for GTEX-1IDJH
# End merging modules for GTEX-1IDJH!
# 0 genes with color grey are excluded from analysis for GTEX-1IKK5
# End merging modules for GTEX-1IKK5!
# 0 genes with color grey are excluded from analysis for GTEX-1IKOH
# End merging modules for GTEX-1IKOH!
# 0 genes with color grey are excluded from analysis for GTEX-1IY9M
# End merging modules for GTEX-1IY9M!
# 0 genes with color grey are excluded from analysis for GTEX-1J1OQ
# End merging modules for GTEX-1J1OQ!
# 0 genes with color grey are excluded from analysis for GTEX-1J8Q2
# End merging modules for GTEX-1J8Q2!
# 0 genes with color grey are excluded from analysis for GTEX-1LVAO
# End merging modules for GTEX-1LVAO!
# 0 genes with color grey are excluded from analysis for GTEX-N7MS
# End merging modules for GTEX-N7MS!
# 2 genes with color grey are excluded from analysis for GTEX-N7MT
# End merging modules for GTEX-N7MT!
# 0 genes with color grey are excluded from analysis for GTEX-NL3H
# End merging modules for GTEX-NL3H!
# 0 genes with color grey are excluded from analysis for GTEX-NL4W
# End merging modules for GTEX-NL4W!
# 0 genes with color grey are excluded from analysis for GTEX-NPJ7
# End merging modules for GTEX-NPJ7!
# 0 genes with color grey are excluded from analysis for GTEX-NPJ8
# End merging modules for GTEX-NPJ8!
# 0 genes with color grey are excluded from analysis for GTEX-OHPN
# End merging modules for GTEX-OHPN!
# 0 genes with color grey are excluded from analysis for GTEX-P44G
# End merging modules for GTEX-P44G!
# 0 genes with color grey are excluded from analysis for GTEX-P44H
# End merging modules for GTEX-P44H!
# 0 genes with color grey are excluded from analysis for GTEX-PWO3
# End merging modules for GTEX-PWO3!
# 0 genes with color grey are excluded from analysis for GTEX-Q2AG
# End merging modules for GTEX-Q2AG!
# 1 genes with color grey are excluded from analysis for GTEX-QDT8
# End merging modules for GTEX-QDT8!
# 0 genes with color grey are excluded from analysis for GTEX-QMR6
# End merging modules for GTEX-QMR6!
# 1 genes with color grey are excluded from analysis for GTEX-QVJO
# End merging modules for GTEX-QVJO!
# 0 genes with color grey are excluded from analysis for GTEX-QVUS
# End merging modules for GTEX-QVUS!
# 0 genes with color grey are excluded from analysis for GTEX-R55E
# End merging modules for GTEX-R55E!
# 1 genes with color grey are excluded from analysis for GTEX-RNOR
# End merging modules for GTEX-RNOR!
# 1 genes with color grey are excluded from analysis for GTEX-RU72
# End merging modules for GTEX-RU72!
# 0 genes with color grey are excluded from analysis for GTEX-S7SE
# End merging modules for GTEX-S7SE!
# 0 genes with color grey are excluded from analysis for GTEX-T2IS
# End merging modules for GTEX-T2IS!
# 0 genes with color grey are excluded from analysis for GTEX-T5JC
# End merging modules for GTEX-T5JC!
# 0 genes with color grey are excluded from analysis for GTEX-T6MN
# End merging modules for GTEX-T6MN!
# 0 genes with color grey are excluded from analysis for GTEX-TSE9
# End merging modules for GTEX-TSE9!
# 0 genes with color grey are excluded from analysis for GTEX-UTHO
# End merging modules for GTEX-UTHO!
# 0 genes with color grey are excluded from analysis for GTEX-WHSE
# End merging modules for GTEX-WHSE!
# 0 genes with color grey are excluded from analysis for GTEX-WL46
# End merging modules for GTEX-WL46!
# 0 genes with color grey are excluded from analysis for GTEX-WVLH
# End merging modules for GTEX-WVLH!
# 1 genes with color grey are excluded from analysis for GTEX-WWYW
# End merging modules for GTEX-WWYW!
# 0 genes with color grey are excluded from analysis for GTEX-WZTO
# End merging modules for GTEX-WZTO!
# 0 genes with color grey are excluded from analysis for GTEX-X261
# End merging modules for GTEX-X261!
# 1 genes with color grey are excluded from analysis for GTEX-X4EP
# End merging modules for GTEX-X4EP!
# 0 genes with color grey are excluded from analysis for GTEX-X4XX
# End merging modules for GTEX-X4XX!
# 2 genes with color grey are excluded from analysis for GTEX-X585
# End merging modules for GTEX-X585!
# 1 genes with color grey are excluded from analysis for GTEX-XLM4
# End merging modules for GTEX-XLM4!
# 0 genes with color grey are excluded from analysis for GTEX-XMD1
# End merging modules for GTEX-XMD1!
# 0 genes with color grey are excluded from analysis for GTEX-Y8DK
# End merging modules for GTEX-Y8DK!
# 1 genes with color grey are excluded from analysis for GTEX-YFC4
# End merging modules for GTEX-YFC4!
# 0 genes with color grey are excluded from analysis for GTEX-YJ89
# End merging modules for GTEX-YJ89!
# 0 genes with color grey are excluded from analysis for GTEX-Z93S
# End merging modules for GTEX-Z93S!
# 1 genes with color grey are excluded from analysis for GTEX-ZAB4
# End merging modules for GTEX-ZAB4!
# 0 genes with color grey are excluded from analysis for GTEX-ZDXO
# End merging modules for GTEX-ZDXO!
# 0 genes with color grey are excluded from analysis for GTEX-ZE7O
# End merging modules for GTEX-ZE7O!
# 1 genes with color grey are excluded from analysis for GTEX-ZE9C
# End merging modules for GTEX-ZE9C!
# 0 genes with color grey are excluded from analysis for GTEX-ZF28
# End merging modules for GTEX-ZF28!
# 0 genes with color grey are excluded from analysis for GTEX-ZUA1
# End merging modules for GTEX-ZUA1!
# 2 genes with color grey are excluded from analysis for GTEX-ZV68
# End merging modules for GTEX-ZV68!
# 0 genes with color grey are excluded from analysis for GTEX-ZVT3
# End merging modules for GTEX-ZVT3!
# 0 genes with color grey are excluded from analysis for GTEX-ZVZQ
# End merging modules for GTEX-ZVZQ!
# 0 genes with color grey are excluded from analysis for GTEX-ZXG5
# End merging modules for GTEX-ZXG5!

# %%
# subject = 'GTEX-1192X'
# # read the allen region prediction
# save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/ATG_8_or_less/Prediction/300_500_by_subject/'
# csv_file = f'{subject}_300_500_trainable_LMfromGTEx.csv'
# go_mat = pd.read_csv(save_dir+csv_file, index_col=0)
# # read the raw module output from WGCNA
# filename = f'{subject}_raw_modules.csv'
# save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/WGCNA/raw_modules/'
# module_df = pd.read_csv(save_dir+filename)
# module_dict = module_df.groupby('Module')['Gene'].apply(list).to_dict()

# # run the script
# output_dict = MERGE_WORKFLOW(go_mat, module_dict)

# %%
# final_dict = {}
# module_list = list(output_dict.keys())
# for key, value in output_dict.items():
#     new_module_name = f'M{module_list.index(key)+1}'
#     final_dict[new_module_name] = value

# data = [(gene, key) for key, genes in final_dict.items() for gene in genes]
# final_mat = pd.DataFrame(data, columns=['gene', 'module'])
# save_dir = '/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/src/Pytorch/02162024/WGCNA/output_modules/'
# final_mat.to_csv(save_dir+f'{subject}_merged_module.csv', index=False)
# # y = pd.read_csv(save_dir+f'{subject}_merged_module.csv')
