# %%
import pandas as pd
from collections import Counter

# %%
ModuleMatch = pd.read_csv('/project/pi_rachel_melamed_uml_edu/Jianfeng/Allen/data/modified_data/ModuleMatch.csv', 
                          index_col=0)

# %%
counter = Counter(ModuleMatch['Module.Label'])

# %%
counter
# Out:
# Counter({'M1': 362,
#          'M10': 139,
#          'M11': 246,
#          'M12': 47,
#          'M13': 85,
#          'M14': 134,
#          'M15': 176,
#          'M16': 100,
#          'M17': 530,
#          'M18': 192,
#          'M19': 921,
#          'M2': 164,
#          'M20': 697,
#          'M21': 237,
#          'M22': 161,
#          'M23': 843,
#          'M24': 974,
#          'M25': 167,
#          'M26': 595,
#          'M27': 741,
#          'M28': 632,
#          'M29': 444,
#          'M3': 224,
#          'M30': 1446,
#          'M31': 490,
#          'M32': 147,
#          'M4': 429,
#          'M5': 155,
#          'M6': 459,
#          'M7': 141,
#          'M8': 192,
#          'M9': 162})
